# %% [markdown]
# # Examen - Probabilités et statistiques
# ## EL BEBLAWY Rami

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

import pickle
import gzip
import urllib.request

# %% [markdown]
# ### Exercice 1
# ### Computing Pi avec Montecarlo

# %%
def estimate_pi(N):
    x = [np.random.uniform(-1,1) for i in range(N)]
    y = [np.random.uniform(-1,1) for i in range(N)]
    in_circle = [1 if np.sqrt(x[i]**2 + y[i]**2) <= 1 else 0 for i in range(N)]
    res = (sum(in_circle)/N) * 4
    return (res, x, y)

# %%
pi = estimate_pi(5000)
print(pi[0])
# Out:
# 3.1352

# %%
def bonus(x,y):
    c = plt.Circle((0,0),1, fill=False, color='orange')
    fig, ax = plt.subplots()
    ax.set_aspect(1)
    ax.add_artist(c)
    ax.plot([-1,1], [1,1], color='green')
    ax.plot([-1,-1], [-1,1], color='green')
    ax.plot([-1,1], [-1,-1], color='green')
    ax.plot([1,1], [1,-1], color='green')
    plt.xlim(-1.1, 1.1)
    plt.ylim(-1.1, 1.1)
    
    N = len(x)
    x_blue = []
    y_blue = []
    x_red = []
    y_red = []
    for i in range(N):
        if np.sqrt(x[i]**2 + y[i]**2) <= 1 :
            x_blue.append(x[i])
            y_blue.append(y[i])
        else:
            x_red.append(x[i])
            y_red.append(y[i])
    
    ax.scatter(x_blue,y_blue, s=1)
    ax.scatter(x_red,y_red, s=1, color='red')
       
    plt.show()

# %%
x, y = pi[1], pi[2]
bonus(x,y)

# %% [markdown]
# ### Exercice 2
# ### Distributions continues

# %% [markdown]
# ### Les questions 1 à 3 sont à la fin du pdf
# L’algorithme d'echantillonnage par transformation inverse consite à tirer des x aléatoires entre 0 et 1 qui sont en fait nos p(x). Ensuite, il suffit de trouver à quelles valeures ces probabilités sont associées pour avoir la distribution

# %%
l=3
N=5000

# %%
def echantillons(N, l):   
    x = np.random.uniform(0,1,5000)
    z = [-l * math.log( 1 - i) for i in x]  
    return z

# %%
b = echantillons(N,l)

# %%
plt.hist(b)
plt.show()

# %%
c = np.random.exponential(l,N)

# %%
plt.hist(c)
plt.show()

# %%
fig, ax = plt.subplots()
plt.hist(c, alpha=0.5, color='green', bins=30)
plt.hist(b, alpha=0.5, color='red', bins=30)
plt.show()

# %%
N = 10000
l = 3
def t(x):
    return x**2

# %%
def q7(N,l):
    x = np.random.exponential(l,N)
    y = [t(i) for i in x]
    m = np.mean(y)
    err = np.sqrt(sum( [((i-m)**2) for i in y] )/N )
    return m,err

# %%
l_res = [q7(N,l) for i in range(N)]

# %%
dqidoj = np.asarray(l_res)
print(dqidoj[:,1])
# Out:
# [40.29886717 41.75458623 38.2072162  ... 40.95993298 41.72506408
#  40.97660253]

# %% [markdown]
# ### Exercice 3
# ### SVD ET MNIST

# %%
local_filename, headers = urllib.request.urlretrieve(
    "http://deeplearning.net/data/mnist/mnist.pkl.gz",
    "mnist.pkl.gz")
html = open(local_filename)
html.close()

f = gzip.open('mnist.pkl.gz', 'rb')
u = pickle._Unpickler(f)
u.encoding = 'latin1'
mnist = u.load()
train_set, valid_set, test_set = mnist

# %%
data = train_set[0].T
svd = np.linalg.svd(data, full_matrices = False)
# On calcule la SVD en gardant uniquement les 784 premières lignes de la matrice V
# Toutes les autres lignes donneraient 0 une fois multipliées avec les autres matrices
# Ainsi, on peut faire rentrer la SVD en mémoire

# %%
print("L'objet SVD est composé de {} matrices.".format(len(svd), l))
print("La première est la matrice de passage, de taille {}x{}".format(len(svd[0]),len(svd[0][0])))
print("La seconde est sigma, la matrice diagonale ici représentée sous forme d'un simple tableau (pour ne pas prendre \ntrop de place en mémoire) mais elle est en réalité de taille {}x{}".format(len(svd[1]),len(svd[1])))
print("La troisième est la matrice de nouvelles coordonnées, de taille {}x{}.".format(len(svd[2]),len(svd[2][0])))
# Out:
# L'objet SVD est composé de 3 matrices.
# La première est la matrice de passage, de taille 784x784
# La seconde est sigma, la matrice diagonale ici représentée sous forme d'un simple tableau (pour ne pas prendre
# trop de place en mémoire) mais elle est en réalité de taille 784x784
# La troisième est la matrice de nouvelles coordonnées, de taille 784x50000.

# %%
for i in range(10):
    arr = svd[0][:,i]
    image = arr.reshape((28,28))
    fig = plt.figure
    plt.imshow(image)
    plt.show()

# %%
X = np.asarray([train_set[0][np.where(train_set[1]==i)] for i in range(10)])

# %%
# X_proj3[i] contient la projection du chiffre i selon les 3 premiers composants

# %%
"""X_proj3 = []
for i in range(10):
    X_proj3.append([])
    for j in X[i]:
        X_proj3[i].append(j@svd[0][:,0:3])"""

# %%
X_proj3 = np.empty(10, dtype=np.ndarray)
for i in range(10):
    X_proj3[i] = np.empty(len(X[i]), dtype=np.ndarray)
    for j in range(len(X[i])):
        X_proj3[i][j] = np.asarray(X[i][j]@svd[0][:,0:3])

# %%
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

# %%
[[plt.scatter(j[0], j[1], color = colors[i],s=1) for j in X_proj3[i]] for i in range(10)]
plt.title("Projection 1-2")
plt.show()

# %%
for i in range(10):
    for j in X_proj3[i]:
        plt.scatter(j[1], j[2], color = colors[i],s=1)

    
plt.title("Projection 1-2")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-281-f360cd60e8e0> in <module>
#       1 for i in range(10):
#       2     for j in X_proj3[i]:
# ----> 3         plt.scatter(j[1], j[2], color = colors[i],s=1)
#       4
#       5
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4464                 self.set_ymargin(0.05)
#    4465
# -> 4466         self.add_collection(collection)
#    4467         self._request_autoscale_view()
#    4468
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in add_collection(self, collection, autolim)
#    1818             # Make sure viewLim is not stale (mostly to match
#    1819             # pre-lazy-autoscale behavior, which is not really better).
# -> 1820             self._unstale_viewLim()
#    1821             self.update_datalim(collection.get_datalim(self.transData))
#    1822
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _unstale_viewLim(self)
#     593             for ax in self._shared_y_axes.get_siblings(self):
#     594                 ax._stale_viewlim_y = False
# --> 595             self.autoscale_view(scalex=scalex, scaley=scaley)
#     596
#     597     @property
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2380             # `get_children` would raise an AttributeError.
#    2381             if self._xmargin and scalex and self._autoscaleXon:
# -> 2382                 x_stickies = np.sort(np.concatenate([
#    2383                     artist.sticky_edges.x
#    2384                     for ax in self._shared_x_axes.get_siblings(self)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7efcc41a28b0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
# -> 2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#    2103                             bbox_extra_artists=bbox_artists)
#    2104                     pad = kwargs.pop("pad_inches", None)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2383
#    2384         for a in artists:
# -> 2385             bbox = a.get_tightbbox(renderer)
#    2386             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2387                 bb.append(bbox)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4353             clip_extent = a._get_clipping_extent_bbox()
#    4354             if clip_extent is not None:
# -> 4355                 clip_extent = mtransforms.Bbox.intersection(clip_extent,
#    4356                     axbbox)
#    4357                 if np.all(clip_extent.extents == axbbox.extents):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/transforms.py in intersection(bbox1, bbox2)
#     717         y0 = np.maximum(bbox1.ymin, bbox2.ymin)
#     718         y1 = np.minimum(bbox1.ymax, bbox2.ymax)
# --> 719         return Bbox([[x0, y0], [x1, y1]]) if x0 <= x1 and y0 <= y1 else None
#     720
#     721
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/transforms.py in __init__(self, points, **kwargs)
#     749         # default or has been mutated; we store the orig points to
#     750         # support the mutated methods
# --> 751         self._points_orig = self._points.copy()
#     752     if DEBUG:
#     753         ___init__ = __init__
#
# KeyboardInterrupt:

# %%
[plt.scatter(X_proj3[i][:,1], X_proj3[i][:,2], color = colors[i],s=1) for i in range(10)] 
plt.title("Projection 1-2")
plt.show()

# %%
print(X_proj3[0])
print(X_proj3[0][:,1])
# Out:
# [array([-6.8450766, -3.5644355, -1.3139137], dtype=float32)
#  array([-7.462906 , -3.4411855, -1.5494119], dtype=float32)
#  array([-8.951382  , -0.21864656, -0.92830133], dtype=float32) ...
#  array([-6.297391  ,  0.70293695,  0.25515   ], dtype=float32)
#  array([-6.4078846, -4.793545 , -1.28579  ], dtype=float32)
#  array([-4.1337986 , -2.6401086 , -0.36250204], dtype=float32)]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-297-7bc5e3c341e2> in <module>
#       1 print(X_proj3[0])
# ----> 2 print(X_proj3[0][:,1])
#
# IndexError: too many indices for array

# %%
type(X_proj3[0])
# Out:
# numpy.ndarray

# %% [markdown]
# ### BONUS

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(proj[:,0], proj[:,1], proj[:,2], s=1, color='brown')

ax.set_xlabel('Direction 1')
ax.set_ylabel('Direction 2')
ax.set_zlabel('Direction 3')

plt.show()
